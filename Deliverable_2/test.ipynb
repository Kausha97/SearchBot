# %%
from deliverable2 import *

# Instantiate the URLValidator class
validator = URLValidator()

# Define user prompt and URL
user_prompt = "Is it okay to drink milk at night or not ?"
url_to_check = "https://www.healthline.com/nutrition/drinking-milk-before-bed"

# Run the validation
result = validator.rate_url_validity(user_prompt, url_to_check)

# Print the results
import json
print(json.dumps(result, indent=2))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-86a0d72513dd> in <cell line: 0>()
# ----> 1 from deliverable2 import *
#       2
#       3 # Instantiate the URLValidator class
#       4 validator = URLValidator()
#       5
#
# ModuleNotFoundError: No module named 'deliverable2'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
